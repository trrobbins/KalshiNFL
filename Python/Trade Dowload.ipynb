# %%
# Standard header to load the Kalshi API and related modules, ensuring the current directory (or "Python" subdirectory) is in the Python path.

from pathlib import Path
import sys

python_dir = Path.cwd()
if not (python_dir / "kalshi_api.py").exists():
    python_dir = Path.cwd() / "Python"

if str(python_dir) not in sys.path:
    sys.path.insert(0, str(python_dir))

from kalshi_api import *
from kalshi_analysis import *
from kalshi_plot import *

# %%
df = get_clean_nba_games(status="settled", limit=500)

# %%
df = get_clean_cfb_games(status="open", limit=500)

# %%
df1 = get_trades("KXNBAGAME-26MAR27ATLBOS-ATL")
df2 = get_trades("KXNFLGAME-26SEP09NESEA-NE")

# %%
LoadMissingNFLTrades(2025)

# %%
LoadMissingNBATrades(2025)

# %%
LoadMissingNHLTrades(2025)

# %%
LoadMissingMLBTrades(2026)
# Out:
# Found 1852 trade files in E:\PredMktData\TradeExports\MLB2026
#
# Processing KXMLBGAME-26JUN051420SFCHC-CHC...
# c:\Users\Owner\Dropbox\ECU Misc\Active Working Papers\Prediction Markets\KalshiNFL\Python\kalshi_api.py:446: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[yes_trades, "price"] = df.loc[yes_trades, "price"].fillna(
# c:\Users\Owner\Dropbox\ECU Misc\Active Working Papers\Prediction Markets\KalshiNFL\Python\kalshi_api.py:450: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[no_trades, "price"] = df.loc[no_trades, "price"].fillna(
# Saved 8947 rows to E:\PredMktData\TradeExports\MLB2026\KXMLBGAME-26JUN051420SFCHC-CHC-Trades.csv
#
# Processing KXMLBGAME-26JUN051420SFCHC-SF...
# Saved 10183 rows to E:\PredMktData\TradeExports\MLB2026\KXMLBGAME-26JUN051420SFCHC-SF-Trades.csv
# c:\Users\Owner\Dropbox\ECU Misc\Active Working Papers\Prediction Markets\KalshiNFL\Python\kalshi_api.py:446: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[yes_trades, "price"] = df.loc[yes_trades, "price"].fillna(
# c:\Users\Owner\Dropbox\ECU Misc\Active Working Papers\Prediction Markets\KalshiNFL\Python\kalshi_api.py:450: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[no_trades, "price"] = df.loc[no_trades, "price"].fillna(
# Empty DataFrame
# Columns: [Ticker, Error]
# Index: []

# %%
LoadMissingCFBTrades(2026)
